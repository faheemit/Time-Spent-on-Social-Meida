# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\fahee\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('time_spend_dataset.csv')
df
# Out:
#      age      gender  time_spent   platform  interests        location  \
# 0     56        male           3  Instagram     Sports  United Kingdom
# 1     46      female           2   Facebook     Travel  United Kingdom
# 2     32        male           8  Instagram     Sports       Australia
# 3     60  non-binary           5  Instagram     Travel  United Kingdom
# 4     25        male           1  Instagram  Lifestlye       Australia
# ..   ...         ...         ...        ...        ...             ...
# 995   22      female           8  Instagram  Lifestlye  United Kingdom
# 996   40  non-binary           6    YouTube     Travel  United Kingdom
# 997   27  non-binary           5    YouTube     Travel  United Kingdom
# 998   61      female           4    YouTube     Sports       Australia
# 999   19      female           8    YouTube     Travel       Australia
#
#     demographics         profession  income  indebt  isHomeOwner  Owns_Car
# ...

# %%
df.describe()
# Out:
#                age   time_spent        income
# count  1000.000000  1000.000000   1000.000000
# mean     40.986000     5.029000  15014.823000
# std      13.497852     2.537834   2958.628221
# min      18.000000     1.000000  10012.000000
# 25%      29.000000     3.000000  12402.250000
# 50%      42.000000     5.000000  14904.500000
# 75%      52.000000     7.000000  17674.250000
# max      64.000000     9.000000  19980.000000

# %%
df.isnull().sum()
# Out:
# age             0
# gender          0
# time_spent      0
# platform        0
# interests       0
# location        0
# demographics    0
# profession      0
# income          0
# indebt          0
# isHomeOwner     0
# Owns_Car        0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'time_spent', 'platform', 'interests', 'location',
#        'demographics', 'profession', 'income', 'indebt', 'isHomeOwner',
#        'Owns_Car'],
#       dtype='object')

# %%
sns.countplot(df['gender'])
# Out:
# C:\Users\fahee\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(df['platform'])
# Out:
# C:\Users\fahee\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='platform', ylabel='count'>

# %%
sns.countplot(df['profession'])
# Out:
# C:\Users\fahee\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='profession', ylabel='count'>

# %%
sns.countplot(df['location'])
# Out:
# C:\Users\fahee\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='location', ylabel='count'>

# %%
sns.countplot(df['isHomeOwner'])
# Out:
# C:\Users\fahee\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='isHomeOwner', ylabel='count'>

# %%
sns.countplot(df['Owns_Car'])
# Out:
# C:\Users\fahee\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Owns_Car', ylabel='count'>

# %%
sns.countplot(df['interests'])
# Out:
# C:\Users\fahee\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='interests', ylabel='count'>

# %%
sns.histplot(data=df, x="platform", hue="gender")
# Out:
# <AxesSubplot:xlabel='platform', ylabel='Count'>

# %%
sns.histplot(data=df, x="platform", hue="profession")
# Out:
# <AxesSubplot:xlabel='platform', ylabel='Count'>

# %%
heat_map = df.corr()

# %%
sns.color_palette("tab10")
sns.heatmap(heat_map, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=df, x="platform", y="time_spent", color= 'red')
# Out:
# <AxesSubplot:xlabel='platform', ylabel='time_spent'>

# %%
sns.lineplot(data=df, x="demographics", y="time_spent", color= 'green')
# Out:
# <AxesSubplot:xlabel='demographics', ylabel='time_spent'>

# %%
sns.lineplot(data=df, x="location", y="time_spent", hue = 'profession', color= 'green')
# Out:
# <AxesSubplot:xlabel='location', ylabel='time_spent'>

# %%
sns.lineplot(data=df, x="gender", y="time_spent", hue = 'profession', color= 'green')
plt.title("Time spent by gender with profession")
# Out:
# Text(0.5, 1.0, 'Time spent by gender with profession')

# %%
df.head()
# Out:
#    age      gender  time_spent   platform  interests        location  \
# 0   56        male           3  Instagram     Sports  United Kingdom
# 1   46      female           2   Facebook     Travel  United Kingdom
# 2   32        male           8  Instagram     Sports       Australia
# 3   60  non-binary           5  Instagram     Travel  United Kingdom
# 4   25        male           1  Instagram  Lifestlye       Australia
#
#   demographics         profession  income  indebt  isHomeOwner  Owns_Car
# 0        Urban  Software Engineer   19774    True        False     False
# 1        Urban            Student   10564    True         True      True
# 2    Sub_Urban   Marketer Manager   13258   False        False     False
# 3        Urban            Student   12500   False         True     False
# 4        Urban  Software Engineer   14566   False         True      True

# %%
sns.violinplot(x = 'time_spent', y = 'age', data = df, hue = 'isHomeOwner', split = True )
# Out:
# <AxesSubplot:xlabel='time_spent', ylabel='age'>

# %%
sns.violinplot(x = 'time_spent', y = 'age', data = df, hue = 'Owns_Car', split = True )
# Out:
# <AxesSubplot:xlabel='time_spent', ylabel='age'>

# %%
sns.violinplot(x = 'platform', y = 'time_spent', data = df, hue = 'gender')
# Out:
# <AxesSubplot:xlabel='platform', ylabel='time_spent'>

# %%
plt.figure(figsize = (15,6))
sns.violinplot(x = 'time_spent', y = 'income', data = df, hue = 'gender')
# Out:
# <AxesSubplot:xlabel='time_spent', ylabel='income'>

# %%
travel  = df[df.interests == 'Travel']
travel
# Out:
#      age      gender  time_spent   platform interests        location  \
# 1     46      female           2   Facebook    Travel  United Kingdom
# 3     60  non-binary           5  Instagram    Travel  United Kingdom
# 5     38        male           3   Facebook    Travel   United States
# 14    41  non-binary           9    YouTube    Travel   United States
# 16    39        male           8  Instagram    Travel   United States
# ..   ...         ...         ...        ...       ...             ...
# 991   20  non-binary           7   Facebook    Travel       Australia
# 992   50      female           9    YouTube    Travel       Australia
# 996   40  non-binary           6    YouTube    Travel  United Kingdom
# 997   27  non-binary           5    YouTube    Travel  United Kingdom
# 999   19      female           8    YouTube    Travel       Australia
#
#     demographics         profession  income  indebt  isHomeOwner  Owns_Car
# ...

# %%
sns.lineplot(data=travel, x="gender", y="time_spent", hue = 'profession', color= 'green')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='time_spent'>

# %%
sns.lineplot(data=travel, x="profession", y="time_spent", hue = 'isHomeOwner', color= 'green')
# Out:
# <AxesSubplot:xlabel='profession', ylabel='time_spent'>

# %%
Sports  = df[df.interests == 'Sports']
Sports
# Out:
#      age      gender  time_spent   platform interests        location  \
# 0     56        male           3  Instagram    Sports  United Kingdom
# 2     32        male           8  Instagram    Sports       Australia
# 6     56        male           8    YouTube    Sports   United States
# 7     36        male           4  Instagram    Sports       Australia
# 9     28  non-binary           2  Instagram    Sports       Australia
# ..   ...         ...         ...        ...       ...             ...
# 979   37      female           6   Facebook    Sports       Australia
# 980   29        male           7    YouTube    Sports  United Kingdom
# 981   64        male           6   Facebook    Sports  United Kingdom
# 982   18      female           9  Instagram    Sports  United Kingdom
# 998   61      female           4    YouTube    Sports       Australia
#
#     demographics         profession  income  indebt  isHomeOwner  Owns_Car
# ...

# %%
lifestyles  = df[df.interests == 'Lifestlye']
lifestyles
# Out:
#      age      gender  time_spent   platform  interests        location  \
# 4     25        male           1  Instagram  Lifestlye       Australia
# 8     40  non-binary           7    YouTube  Lifestlye       Australia
# 10    28      female           7    YouTube  Lifestlye  United Kingdom
# 13    57      female           6  Instagram  Lifestlye  United Kingdom
# 26    39        male           2  Instagram  Lifestlye       Australia
# ..   ...         ...         ...        ...        ...             ...
# 989   30      female           7  Instagram  Lifestlye       Australia
# 990   60      female           9    YouTube  Lifestlye       Australia
# 993   23      female           3    YouTube  Lifestlye   United States
# 994   27  non-binary           4  Instagram  Lifestlye   United States
# 995   22      female           8  Instagram  Lifestlye  United Kingdom
#
#     demographics         profession  income  indebt  isHomeOwner  Owns_Car
# ...

# %%
sns.barplot(x = 'gender', y = 'time_spent', data = Sports)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='time_spent'>

# %%
sns.barplot(x = 'gender', y = 'time_spent', data = travel)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='time_spent'>

# %%
sns.barplot(x = 'gender', y = 'time_spent', data = lifestyles)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='time_spent'>

# %%
sns.barplot(x = 'gender', y = 'time_spent', data = df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='time_spent'>

# %%
sns.boxplot(x = 'profession', y = 'income', data = df, hue = 'platform' )
# Out:
# <AxesSubplot:xlabel='profession', ylabel='income'>

# %%
sns.boxplot(x = 'profession', y = 'time_spent', data = df, hue = 'platform' )
# Out:
# <AxesSubplot:xlabel='profession', ylabel='time_spent'>

# %%
sns.boxplot(x = 'profession', y = 'time_spent', data = df, hue = 'interests' )
# Out:
# <AxesSubplot:xlabel='profession', ylabel='time_spent'>

# %%
sns.boxplot(x = 'profession', y = 'time_spent', data = df, hue = 'isHomeOwner' )
# Out:
# <AxesSubplot:xlabel='profession', ylabel='time_spent'>

# %%
australia =  df[df.location == 'Australia']
australia
# Out:
#      age      gender  time_spent   platform  interests   location  \
# 2     32        male           8  Instagram     Sports  Australia
# 4     25        male           1  Instagram  Lifestlye  Australia
# 7     36        male           4  Instagram     Sports  Australia
# 8     40  non-binary           7    YouTube  Lifestlye  Australia
# 9     28  non-binary           2  Instagram     Sports  Australia
# ..   ...         ...         ...        ...        ...        ...
# 990   60      female           9    YouTube  Lifestlye  Australia
# 991   20  non-binary           7   Facebook     Travel  Australia
# 992   50      female           9    YouTube     Travel  Australia
# 998   61      female           4    YouTube     Sports  Australia
# 999   19      female           8    YouTube     Travel  Australia
#
#     demographics         profession  income  indebt  isHomeOwner  Owns_Car
# 2      Sub_Urban   Marketer Manager   13258   False        False     False
# ...

# %%
sns.barplot(x=df["time_spent"],y=df["age"],hue=df["gender"])
# Out:
# <AxesSubplot:xlabel='time_spent', ylabel='age'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(data = df,hue="time_spent",y="age",x="location")
# Out:
# <AxesSubplot:xlabel='location', ylabel='age'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(data = df,hue="time_spent",y="age",x="profession")
# Out:
# <AxesSubplot:xlabel='profession', ylabel='age'>

# %%
plt.figure(figsize=(20, 10))
sns.kdeplot(data = df, x = 'time_spent', hue = 'demographics', fill = True)
plt.title('KDE Plot of demographics')
plt.xlabel('Times spent on Social Media')
plt.show()

# %%
sns.scatterplot( x = df['time_spent'], y = df['age'])
# Out:
# <AxesSubplot:xlabel='time_spent', ylabel='age'>

# %%
sns.scatterplot( x = df['time_spent'], y = df['income'], hue=df['demographics'])
# Out:
# <AxesSubplot:xlabel='time_spent', ylabel='income'>

# %%
sns.scatterplot( x = df['location'], y = df['interests'], hue=df['indebt'])
# Out:
# <AxesSubplot:xlabel='location', ylabel='interests'>

# %%
df.head()
# Out:
#    age      gender  time_spent   platform  interests        location  \
# 0   56        male           3  Instagram     Sports  United Kingdom
# 1   46      female           2   Facebook     Travel  United Kingdom
# 2   32        male           8  Instagram     Sports       Australia
# 3   60  non-binary           5  Instagram     Travel  United Kingdom
# 4   25        male           1  Instagram  Lifestlye       Australia
#
#   demographics         profession  income  indebt  isHomeOwner  Owns_Car
# 0        Urban  Software Engineer   19774    True        False     False
# 1        Urban            Student   10564    True         True      True
# 2    Sub_Urban   Marketer Manager   13258   False        False     False
# 3        Urban            Student   12500   False         True     False
# 4        Urban  Software Engineer   14566   False         True      True
